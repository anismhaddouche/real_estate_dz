# %%
from pathlib import Path
import pandas as pd 
import json

# %%
raw_data_path = Path("../data/0_raw_data__0.json")

# %%
with open(raw_data_path, 'r') as json_file:
    raw_data = json.load(json_file)

asset = pd.DataFrame([item for sublist in raw_data for item in sublist])

# %%
asset
# Out:
#            id                                             title  \
# 0    37280677        Location Appartement F2 Alger Alger centre
# 1    36715463  Location Niveau De Villa F2 Alger Les eucalyptus
# 2    32364831                     Location Immeuble Alger Hydra
# 3    36841411                       Location Local Alger Draria
# 4    37263055                 Location Appartement F3 Oran Oran
# ..        ...                                               ...
# 115  35611731           Location Appartement F4 Alger El achour
# 116  37162817                        Location Villa Alger Kouba
# 117  37172787             Location Appartement F3 Alger Cheraga
# 118  37278895        Location Appartement F5 Alger Said hamdine
# 119  36877975           Location Appartement F3 Alger El achour
#
#                                                   slug  \
# 0         appartement-location-f2-alger-centre-algerie
# 1    niveau-de-villa-location-f2-alger-les-eucalypt...
# 2                immeuble-location-alger-hydra-algerie
# 3                  local-location-alger-draria-algerie
# 4                 appartement-location-f3-oran-algerie
# ..                                                 ...
# 115    appartement-location-f4-alger-el-achour-algerie
# 116                 villa-location-alger-kouba-algerie
# 117      appartement-location-f3-alger-cheraga-algerie
# 118  appartement-location-f5-alger-said-hamdine-alg...
# 119    appartement-location-f3-alger-el-achour-algerie
#
#                                            description  showAnalytics  \
# 0    Agence loue un duplex en plein centre d'alger ...           True
# 1    lagence immo rissala met en location f2 1er et...           True
# 2    l'agence immobilière el sol met en location un...           True
# 3    J'ai un local à loué de 28 m2 avec sanitaire7 ...           True
# 4    A LOUER VIDE F3 83 M2 GAMBETTA SODA RUCH 2ème ...           True
# ..                                                 ...            ...
# 115  Loue un jolie appartement F4 avec cuisine équi...           True
# 116  Loue une villa de 330m²/190m² lotissement Al M...           True
# 117  Loue un jolie F3 équipé est meublée de tout au...           True
# 118  Said Hamdine côté fac de droit location F5 nou...           True
# 119  Immo souhaib ment en location un appartement a...           True
#
#                     createdAt  isFromStore                     category  \
# 0    2023-08-16T16:17:01.000Z         True      {'name': 'Appartement'}
# 1    2023-08-16T16:16:05.000Z         True  {'name': 'Niveau De Villa'}
# 2    2023-08-16T16:15:15.000Z         True         {'name': 'Immeuble'}
# 3    2023-08-16T15:40:00.000Z        False            {'name': 'Local'}
# 4    2023-08-16T15:39:31.000Z        False      {'name': 'Appartement'}
# ..                        ...          ...                          ...
# 115  2023-08-16T14:24:54.000Z         True      {'name': 'Appartement'}
# 116  2023-08-16T14:24:54.000Z         True            {'name': 'Villa'}
# 117  2023-08-16T14:24:54.000Z         True      {'name': 'Appartement'}
# 118  2023-08-16T14:20:41.000Z         True      {'name': 'Appartement'}
# 119  2023-08-16T14:16:12.000Z         True      {'name': 'Appartement'}
#
#      likeCount     status  ... specs  \
# 0            0  PUBLISHED  ...  None
# 1            3  PUBLISHED  ...  None
# 2            0  PUBLISHED  ...  None
# 3            0  PUBLISHED  ...  None
# 4            0     EDITED  ...  None
# ..         ...        ...  ...   ...
# 115          0  PUBLISHED  ...  None
# 116          0  PUBLISHED  ...  None
# 117          0  PUBLISHED  ...  None
# 118          0  PUBLISHED  ...  None
# 119          0  PUBLISHED  ...  None
#
#                                                  store               user  \
# 0    {'id': '10239', 'name': 'Le vieux carré', 'slu...  {'id': '3517544'}
# 1    {'id': '1245', 'name': 'Agence EL-RISSALA', 's...   {'id': '375790'}
# 2    {'id': '1338', 'name': 'Agence El SOL', 'slug'...   {'id': '415632'}
# 3                                                 None  {'id': '9316175'}
# 4                                                 None  {'id': '3630070'}
# ..                                                 ...                ...
# 115  {'id': '10606', 'name': 'AG Ibnsina', 'slug': ...  {'id': '3629374'}
# 116  {'id': '10606', 'name': 'AG Ibnsina', 'slug': ...  {'id': '3629374'}
# 117  {'id': '10606', 'name': 'AG Ibnsina', 'slug': ...  {'id': '3629374'}
# 118  {'id': '16695', 'name': 'Dady transaction', 's...  {'id': '6266118'}
# 119  {'id': '5039', 'name': 'Immo Souhaib', 'slug':...  {'id': '1465034'}
#
#           price pricePreview  priceUnit  oldPrice   priceType  \
# 0         55000      55000.0       UNIT       NaN  NEGOTIABLE
# 1         20000          2.0    MILLION       NaN       FIXED
# 2       1600000        160.0    MILLION       NaN  NEGOTIABLE
# 3     300000000      30000.0    MILLION       NaN        None
# 4         65000      65000.0       UNIT       NaN  NEGOTIABLE
# ..          ...          ...        ...       ...         ...
# 115       70000      70000.0       UNIT       NaN  NEGOTIABLE
# 116  4000000000     400000.0    MILLION       NaN  NEGOTIABLE
# 117  1300000000     130000.0    MILLION       NaN       FIXED
# 118      150000         15.0    MILLION       NaN        None
# 119       32000      32000.0       UNIT       NaN        None
#
#          exchangeType             smallDescription
# 0                None   [{'valueText': ['50 m²']}]
# 1                None   [{'valueText': ['60 m²']}]
# 2    NOT_EXCHANGEABLE  [{'valueText': ['600 m²']}]
# 3                None   [{'valueText': ['28 m²']}]
# 4    NOT_EXCHANGEABLE   [{'valueText': ['83 m²']}]
# ..                ...                          ...
# 115              None  [{'valueText': ['100 m²']}]
# 116              None  [{'valueText': ['330 m²']}]
# 117              None   [{'valueText': ['80 m²']}]
# 118              None  [{'valueText': ['125 m²']}]
# 119              None   [{'valueText': ['75 m²']}]
#
# [120 rows x 22 columns]

# %%
asset["specs"]
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 115    None
# 116    None
# 117    None
# 118    None
# 119    None
# Name: specs, Length: 120, dtype: object

# %%
cleaned_data = pd.read_parquet("/Users/anis/Desktop/mlopszoomcamp_2023_project/data/1_cleaned_data.parquet")

# %%
cleaned_data.columns
# Out:
# Index(['id', 'category', 'slug', 'description', 'price', 'priceType',
#        'priceUnit', 'wilaya', 'commune', 'createdAt', 'likeCount',
#        'isFromStore', 'store', 'location_duree', 'superficie', 'pieces',
#        'asset-in-a-promotional-site', 'property-specifications', 'papers',
#        'etages', 'sale-by-real-estate-agent', 'property-payment-conditions',
#        'medias'],
#       dtype='object')

# %%
asset.columns
# Out:
# Index(['id', 'title', 'slug', 'description', 'showAnalytics', 'createdAt',
#        'isFromStore', 'category', 'likeCount', 'status', 'cities', 'medias',
#        'specs', 'store', 'user', 'price', 'pricePreview', 'priceUnit',
#        'oldPrice', 'priceType', 'exchangeType', 'smallDescription'],
#       dtype='object')
