# %%
from pathlib import Path
import pandas as pd 
import json

# %%
raw_data_path = Path("../data/0_raw_data.json")

# %%
with open(raw_data_path, 'r') as json_file:
    raw_data = json.load(json_file)

asset = pd.DataFrame([item for sublist in raw_data for item in sublist])

# %%
asset
# Out:
#              id                                          title  \
# 0      33222528      Location Appartement F3 Alger Ouled fayet
# 1      34006560  Location Appartement F2 Alger Bordj el kiffan
# 2      34342789            Location Appartement F8 Alger Hydra
# 3      34568605                 Location Local Alger Birkhadem
# 4      34326841  Location Appartement F3 Alger Bordj el kiffan
# ...         ...                                            ...
# 40411   2101527            Location Appartement F4 Alger Hydra
# 40412   3019544                     Location Villa Alger Hydra
# 40413   2912804     Location Niveau De Villa Alger Hussein dey
# 40414   2640386            Location Appartement F4 Alger Hydra
# 40415   2597859                 Location Local Alger Birkhadem
#
#                                                     slug  \
# 0      appartement-location-f3-alger-ouled-fayet-algerie
# 1      appartement-location-f2-alger-bordj-el-kiffan-...
# 2            appartement-location-f8-alger-hydra-algerie
# 3                 local-location-alger-birkhadem-algerie
# 4      appartement-location-f3-alger-bordj-el-kiffan-...
# ...                                                  ...
# 40411        alger-hydra-algerie-appartement-location-f4
# 40412                 alger-hydra-algerie-villa-location
# 40413  alger-hussein-dey-algerie-niveau-de-villa-loca...
# 40414        alger-hydra-algerie-appartement-location-f4
# 40415             alger-birkhadem-algerie-local-location
#
#                                              description  showAnalytics  \
# 0      Offer de location d'un  bell appartement  f3 d...           True
# 1      Agence immobilière \n***** EL DJAZAIRIA *****\...          False
# 2      Agence immobilier met en location appartement ...           True
# 3      Agence loue local commercial de villa situe à ...           True
# 4      Agence immobilière\n***** EL DJAZAIRIA *****\n...          False
# ...                                                  ...            ...
# 40411  Bureau d'Affaires Orchidée met en location un ...           True
# 40412  Bureau d'Affaires Orchidée, met en location un...           True
# 40413  le patrimoine loue un jolie f3 70 m toutes com...           True
# 40414  Bureau d'Affaires Orchidée met en location un ...           True
# 40415  Bureau d'Affaires Orchidée met en location un ...           True
#
#                       createdAt  isFromStore                     category  \
# 0      2022-12-20T01:50:31.000Z        False      {'name': 'Appartement'}
# 1      2022-12-20T01:45:06.000Z         True      {'name': 'Appartement'}
# 2      2022-12-20T01:37:03.000Z        False      {'name': 'Appartement'}
# 3      2022-12-20T01:30:17.000Z         True            {'name': 'Local'}
# 4      2022-12-20T01:30:07.000Z         True      {'name': 'Appartement'}
# ...                         ...          ...                          ...
# 40411  2013-06-18T07:48:52.000Z         True      {'name': 'Appartement'}
# 40412  2013-05-15T08:28:28.000Z         True            {'name': 'Villa'}
# 40413  2013-05-05T12:01:16.000Z         True  {'name': 'Niveau De Villa'}
# 40414  2013-03-09T08:40:17.000Z         True      {'name': 'Appartement'}
# 40415  2013-02-25T19:49:18.000Z         True            {'name': 'Local'}
#
#        likeCount     status  ...  \
# 0              2  PUBLISHED  ...
# 1              0  PUBLISHED  ...
# 2              1  PUBLISHED  ...
# 3              0  PUBLISHED  ...
# 4              0  PUBLISHED  ...
# ...          ...        ...  ...
# 40411          0  PUBLISHED  ...
# 40412          0  PUBLISHED  ...
# 40413          1  PUBLISHED  ...
# 40414          0  PUBLISHED  ...
# 40415          0  PUBLISHED  ...
#
#                                                    specs  \
# 0      [{'specification': {'label': 'Paiement par', '...
# 1      [{'specification': {'label': 'Paiement par', '...
# 2      [{'specification': {'label': 'Paiement par', '...
# 3      [{'specification': {'label': 'Superficie', 'co...
# 4      [{'specification': {'label': 'Paiement par', '...
# ...                                                  ...
# 40411  [{'specification': {'label': 'Superficie', 'co...
# 40412  [{'specification': {'label': 'Superficie', 'co...
# 40413  [{'specification': {'label': 'Superficie', 'co...
# 40414  [{'specification': {'label': 'Superficie', 'co...
# 40415  [{'specification': {'label': 'Superficie', 'co...
#
#                                                    store               user  \
# 0                                                   None  {'id': '7029337'}
# 1      {'id': '13319', 'name': 'Agence Immobilière EL...   {'id': '836448'}
# 2                                                   None  {'id': '6975347'}
# 3      {'id': '1793', 'name': 'Agence Le Premier Pas'...   {'id': '612749'}
# 4      {'id': '13319', 'name': 'Agence Immobilière EL...   {'id': '836448'}
# ...                                                  ...                ...
# 40411  {'id': '1514', 'name': 'Bureau d'Affaires Orch...   {'id': '401194'}
# 40412  {'id': '1514', 'name': 'Bureau d'Affaires Orch...   {'id': '401194'}
# 40413  {'id': '1618', 'name': 'Agence Immobilière ', ...   {'id': '542213'}
# 40414  {'id': '1514', 'name': 'Bureau d'Affaires Orch...   {'id': '401194'}
# 40415  {'id': '1514', 'name': 'Bureau d'Affaires Orch...   {'id': '401194'}
#
#           price pricePreview  priceUnit  oldPrice   priceType  \
# 0       80000.0          8.0    MILLION       NaN        None
# 1       45000.0      45000.0       UNIT       NaN       FIXED
# 2      150000.0         15.0    MILLION       NaN  NEGOTIABLE
# 3      110000.0     110000.0       UNIT       NaN        None
# 4       45000.0      45000.0       UNIT       NaN  NEGOTIABLE
# ...         ...          ...        ...       ...         ...
# 40411  200000.0     200000.0       UNIT       NaN     OFFERED
# 40412  800000.0     800000.0       UNIT       NaN  NEGOTIABLE
# 40413   50000.0          5.0    MILLION       NaN  NEGOTIABLE
# 40414  150000.0     150000.0       UNIT       NaN  NEGOTIABLE
# 40415   45000.0      45000.0       UNIT       NaN  NEGOTIABLE
#
#            exchangeType             smallDescription
# 0                  None   [{'valueText': ['87 m²']}]
# 1      NOT_EXCHANGEABLE   [{'valueText': ['49 m²']}]
# 2                  None  [{'valueText': ['250 m²']}]
# 3                  None   [{'valueText': ['95 m²']}]
# 4      NOT_EXCHANGEABLE   [{'valueText': ['90 m²']}]
# ...                 ...                          ...
# 40411              None                           []
# 40412              None                           []
# 40413              None                           []
# 40414              None                           []
# 40415              None                           []
#
# [40416 rows x 22 columns]

# %%
asset["createdAt"]
# Out:
# 0        2022-12-20T01:50:31.000Z
# 1        2022-12-20T01:45:06.000Z
# 2        2022-12-20T01:37:03.000Z
# 3        2022-12-20T01:30:17.000Z
# 4        2022-12-20T01:30:07.000Z
#                    ...
# 40411    2013-06-18T07:48:52.000Z
# 40412    2013-05-15T08:28:28.000Z
# 40413    2013-05-05T12:01:16.000Z
# 40414    2013-03-09T08:40:17.000Z
# 40415    2013-02-25T19:49:18.000Z
# Name: createdAt, Length: 40416, dtype: object

# %%
cleaned_data = pd.read_parquet("/Users/anis/Desktop/mlopszoomcamp_2023_project/data/1_cleaned_data.parquet")

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40416 entries, 0 to 40415
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           40416 non-null  int64
#  1   category                     40416 non-null  category
#  2   slug                         40416 non-null  string
#  3   description                  38541 non-null  string
#  4   price                        40416 non-null  float64
#  5   priceType                    30872 non-null  category
#  6   priceUnit                    40416 non-null  category
#  7   wilaya                       40390 non-null  category
#  8   commune                      40390 non-null  category
#  9   createdAt                    40416 non-null  datetime64[ns, UTC]
#  10  likeCount                    40416 non-null  int64
#  11  isFromStore                  40416 non-null  bool
#  12  store                        17796 non-null  object
#  13  location_duree               31715 non-null  Int64
#  14  superficie                   36549 non-null  Int64
#  15  pieces                       30195 non-null  Int64
#  16  asset-in-a-promotional-site  40416 non-null  bool
#  17  property-specifications      26880 non-null  category
#  18  papers                       9424 non-null   category
#  19  etages                       27538 non-null  Int64
#  20  sale-by-real-estate-agent    40416 non-null  bool
#  21  property-payment-conditions  3901 non-null   category
#  22  medias                       40416 non-null  object
# dtypes: Int64(4), bool(3), category(8), datetime64[ns, UTC](1), float64(1), int64(2), object(2), string(2)
# memory usage: 4.4+ MB

# %%
def ma_func(): 
    
    def get_commune(x: list):
        """get the commune column"""
        # x = list_to_dict(x)
        try:
            commune = x[0]["name"]
        except:
            commune = None
        return commune


    def get_wilaya(x: list):
        """get the wilaya column"""
        # x = list_to_dict(x)
        try:
            wilaya = x[0]["region"]["name"]
        except:
            wilaya = None
        return wilaya

# %%
ma_func()

# %%
get_commune()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 get_commune()
#
# NameError: name 'get_commune' is not defined
